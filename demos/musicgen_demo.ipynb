# %% [markdown]
# # MusicGen
# Welcome to MusicGen's demo jupyter notebook. Here you will find a series of self-contained examples of how to use MusicGen in different settings.
#
# First, we start by initializing MusicGen, you can choose a model from the following selection:
# 1. `facebook/musicgen-small` - 300M transformer decoder.
# 2. `facebook/musicgen-medium` - 1.5B transformer decoder.
# 3. `facebook/musicgen-melody` - 1.5B transformer decoder also supporting melody conditioning.
# 4. `facebook/musicgen-large` - 3.3B transformer decoder.
#
# We will use the `facebook/musicgen-small` variant for the purpose of this demonstration.

# %%
# !pip install -U audiocraft
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting audiocraft
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/57/a9/444ad0d90af627237dbaad02d4f4a7be5445af47fefa558daf793a063f78/audiocraft-0.0.2.tar.gz (423 kB)
# Collecting av
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7c/7c/76633096637961155c02a7a082a697c70a992c757e11e20d176f21d3dead/av-10.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 42.1 MB/s eta 0:00:01
# Collecting einops
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/68/24/b05452c986e8eff11f47e123a40798ae693f2fa1ed2f9546094997d2f6be/einops-0.6.1-py3-none-any.whl (42 kB)
# Collecting flashy>=0.0.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/32/1b/262b98d72cfafb16e1fbdb4529fd806da9f7975ca67531854ab2a75f7d22/flashy-0.0.2.tar.gz (72 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting hydra-core>=1.1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/c6/50/e0edd38dcd63fb26a8547f13d28f7a008bc4a3fd4eb4ff030673f22ad41a/hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Collecting hydra_colorlog
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/40/50/a08b0453c18088da369991d015ef3902a9ab532b515a41f1bfbe1394854d/hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Collecting julius
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a1/19/c9e1596b5572c786b93428d0904280e964c930fae7e6c9368ed9e1b63922/julius-0.2.7.tar.gz (59 kB)
# Collecting num2words
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/eb/09/b14d798bc02411b1e5a9896d680f8f417cadc53232bbf7ae9d30263dcf45/num2words-0.5.12-py3-none-any.whl (125 kB)
# Requirement already satisfied: numpy in /home/litingyu/anaconda3/lib/python3.9/site-packages (from audiocraft) (1.21.5)
# Requirement already satisfied: sentencepiece in /home/litingyu/anaconda3/lib/python3.9/site-packages (from audiocraft) (0.1.97)
# Collecting spacy==3.5.2
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ed/46/4192342debf3bbb6fda82e4c67f68d881f9819116cd15721a39f5a3850f5/spacy-3.5.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 21.7 MB/s eta 0:00:01
# Collecting torch>=2.0.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/e5/9a/ce0fe125f226ffce8deba6a18bd8d0b9f589aa236780a83a6d70b5525f56/torch-2.0.1-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
#      |████████████████████████████████| 619.9 MB 47 kB/s s eta 0:00:013ta 0:00:04
# Collecting torchaudio>=2.0.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/eb/b0/b72708eca97014d756e4be2b92eca53e23a202028a24a5e0482adca8d6f7/torchaudio-2.0.2-cp39-cp39-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 30.9 MB/s eta 0:00:01
# Collecting huggingface_hub
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/7f/c4/adcbe9a696c135578cabcbdd7331332daad4d49b7c43688bc2d36b3a47d2/huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
# Requirement already satisfied: tqdm in /home/litingyu/anaconda3/lib/python3.9/site-packages (from audiocraft) (4.64.0)
# Collecting transformers
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/21/02/ae8e595f45b6c8edee07913892b3b41f5f5f273962ad98851dc6a564bbb9/transformers-4.31.0-py3-none-any.whl (7.4 MB)
# Collecting xformers
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/65/d4/5dbc2ef18400c677dfd6ddf469755997a945fbcbe428bdd6ee5302238040/xformers-0.0.20-cp39-cp39-manylinux2014_x86_64.whl (109.1 MB)
#      |████████████████████████████████| 109.1 MB 21.5 MB/s eta 0:00:01
# Collecting demucs
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a0/4d/d5ab8bb1be0c2b066e9ca65ee74b124e791d491534d397da5bfe7a9a60f7/submitit-1.4.5-py3-none-any.whl (73 kB)
# Collecting retrying
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/8f/04/9e36f28be4c0532c0e9207ff9dc01fb13a2b0eb036476a213b0000837d0e/retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: matplotlib~=3.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio->audiocraft) (3.5.1)
# Collecting mdit-py-plugins<=0.3.3
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/33/eb/c358112e8265f827cf8228eda36cf2a720ad933f5ca66f47f808edf4bb34/mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
# Collecting aiofiles<24.0,>=22.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/c5/19/5af6804c4cc0fed83f47bff6e413a98a36618e7d40185cd36e69737f3b0e/aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio->audiocraft) (2.2.0)
# Collecting websockets<12.0,>=10.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a6/9c/2356ecb952fd3992b73f7a897d65e57d784a69b94bb8d8fd5f97531e5c02/websockets-11.0.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      |████████████████████████████████| 129 kB 14.2 MB/s eta 0:00:01
# Collecting pydub
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a6/53/d78dc063216e62fc55f6b2eebb447f6a4b0a59f55c8406376f76bf959b08/pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: aiohttp~=3.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio->audiocraft) (3.8.1)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio->audiocraft) (9.0.1)
# Collecting altair<6.0,>=4.2.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/b2/20/5c3b89d6f8d9938325a9330793438389e0dc94c34d921f6da35ec62095f3/altair-5.0.1-py3-none-any.whl (471 kB)
# Collecting ffmpy
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/9a/06/49b275a312eb207e2a2718a7414dedfded05088437352b67aaa9a355f948/ffmpy-0.3.1.tar.gz (5.5 kB)
# Collecting orjson~=3.0
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ba/7b/62bea88e55c567badfa02d5b60b2bc8285c3fecb6d1b31b1369ab4fb41ab/orjson-3.9.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      |████████████████████████████████| 139 kB 16.5 MB/s eta 0:00:01
# Collecting semantic-version~=2.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/6a/23/8146aad7d88f4fcb3a6218f41a60f6c2d4e3a72de72da1825dc7c8f7877c/semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting uvicorn>=0.14.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/79/96/b0882a1c3f7ef3dd86879e041212ae5b62b4bd352320889231cc735a8e8f/uvicorn-0.23.2-py3-none-any.whl (59 kB)
# Collecting importlib-resources<7.0,>=1.3
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/25/d4/592f53ce2f8dde8be5720851bd0ab71cc2e76c55978e4163ef1ab7e389bb/importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Collecting python-multipart
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/b4/ff/b1e11d8bffb5e0e1b6d27f402eeedbeb9be6df2cdbc09356a1ae49806dbf/python_multipart-0.0.6-py3-none-any.whl (45 kB)
# Collecting gradio-client>=0.4.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/85/29/f3b1e5f54b893665cd703a9ad3b67e534d50c5a2cf14557571a8bb91b0d8/gradio_client-0.4.0-py3-none-any.whl (297 kB)
# Collecting fastapi
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/09/ae/8378894f9fbdf0297cdffdc79496ccd779166d675fec47cad8d2ca782739/fastapi-0.101.1-py3-none-any.whl (65 kB)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio->audiocraft) (1.4.2)
# Requirement already satisfied: markupsafe~=2.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio->audiocraft) (2.0.1)
# Collecting httpx
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ec/91/e41f64f03d2a13aee7e8c819d82ee3aa7cdc484d18c0ae859742597d5aa0/httpx-0.24.1-py3-none-any.whl (75 kB)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from aiohttp~=3.0->gradio->audiocraft) (4.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from aiohttp~=3.0->gradio->audiocraft) (1.6.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from aiohttp~=3.0->gradio->audiocraft) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from aiohttp~=3.0->gradio->audiocraft) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from aiohttp~=3.0->gradio->audiocraft) (5.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from aiohttp~=3.0->gradio->audiocraft) (1.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio->audiocraft) (4.4.0)
# Requirement already satisfied: toolz in /home/litingyu/anaconda3/lib/python3.9/site-packages (from altair<6.0,>=4.2.0->gradio->audiocraft) (0.11.2)
# Requirement already satisfied: fsspec in /home/litingyu/anaconda3/lib/python3.9/site-packages (from gradio-client>=0.4.0->gradio->audiocraft) (2022.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from importlib-resources<7.0,>=1.3->gradio->audiocraft) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->audiocraft) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio->audiocraft) (0.1.2)
# Collecting linkify-it-py<3,>=1
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/1f/1a/16b0d2f66601ba3081f1d4177087c79fd1f11d17706ee01d373e4ba8e00d/linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Collecting uc-micro-py
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/d1/1c/5aeb94aa980da111e4fd0c0fbe5ad95ed5bf9bd957f8e2a6178b85ff4da8/uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: cycler>=0.10 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio->audiocraft) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio->audiocraft) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio->audiocraft) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from matplotlib~=3.0->gradio->audiocraft) (1.3.2)
# Requirement already satisfied: pytz>=2020.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from pandas<3.0,>=1.0->gradio->audiocraft) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio->audiocraft) (1.16.0)
# Collecting h11>=0.8
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting starlette<0.28.0,>=0.27.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/58/f8/e2cca22387965584a409795913b774235752be4176d276714e15e1a58884/starlette-0.27.0-py3-none-any.whl (66 kB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from starlette<0.28.0,>=0.27.0->fastapi->gradio->audiocraft) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi->gradio->audiocraft) (1.2.0)
# Collecting httpcore<0.18.0,>=0.15.0
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/94/2c/2bde7ff8dd2064395555220cbf7cba79991172bf5315a07eb3ac7688d9f1/httpcore-0.17.3-py3-none-any.whl (74 kB)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (1.0.2)
# Requirement already satisfied: resampy>=0.2.2 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (0.4.0)
# Requirement already satisfied: scipy>=1.2.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (1.7.3)
# Requirement already satisfied: soundfile>=0.10.2 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (1.1.0)
# Requirement already satisfied: audioread>=2.1.9 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (3.0.0)
# Requirement already satisfied: numba>=0.45.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (0.55.1)
# Requirement already satisfied: decorator>=4.0.10 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from librosa->audiocraft) (5.1.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa->audiocraft) (0.38.0)
# Requirement already satisfied: appdirs>=1.3.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa->audiocraft) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa->audiocraft) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa->audiocraft) (1.15.0)
# Requirement already satisfied: pycparser in /home/litingyu/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->audiocraft) (2.21)
# Collecting docopt>=0.6.2
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a2/55/8f8cab2afd404cf578136ef2cc5dfb50baa1761b68c9da1fb1e4eed343c9/docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: cloudpickle>=1.2.1 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from submitit->dora-search->flashy>=0.0.1->audiocraft) (2.0.0)
# Requirement already satisfied: mpmath>=0.19 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from sympy->torch>=2.0.0->audiocraft) (1.2.1)
# Collecting safetensors>=0.3.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/61/57/402c6a522f26e6bdc8d46cce379bf20f40daa0764578510e4e8a3d3ed1a9/safetensors-0.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 19.2 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from transformers->audiocraft) (2022.3.15)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/d6/27/07a337087dd507170a1b20fed3bbf8da81401185a7130a6e74e440c52040/tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 24.0 MB/s eta 0:00:01
# Collecting pyre-extensions==0.0.29
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/ce/96/2fd3042ad8b21278f22b7de116b1489e286c445f07c309c85221db86f120/pyre_extensions-0.0.29-py3-none-any.whl (12 kB)
# Collecting typing-inspect
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/litingyu/anaconda3/lib/python3.9/site-packages (from typing-inspect->pyre-extensions==0.0.29->xformers->audiocraft) (0.4.3)
# Building wheels for collected packages: audiocraft, flashy, antlr4-python3-runtime, demucs, julius, dora-search, ffmpy, lit, docopt, treetable
#   Building wheel for audiocraft (setup.py) ... done
#   Created wheel for audiocraft: filename=audiocraft-0.0.2-py3-none-any.whl size=113500 sha256=c419195e4633c654e3b2788cbc829e58fb447f6504b845a04c343d1b1682ce8e
#   Stored in directory: /home/litingyu/.cache/pip/wheels/f7/82/48/6f2740eedcabc536ec485711968170e3deffa2125dfd6aba51
#   Building wheel for flashy (PEP 517) ... done
#   Created wheel for flashy: filename=flashy-0.0.2-py3-none-any.whl size=34526 sha256=d478646767250ac17f4a35be94d43ff9c30869da1ab5fc76fbdaa8eb50477fe0
#   Stored in directory: /home/litingyu/.cache/pip/wheels/19/09/30/dd53fa28edd19d0a19c2fd28969add20aa5e6f1e85daed6bf8
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=a06a2d82e33a4aa3c3c35d887e5f4555c02801a452968433b62781143b6efa35
#   Stored in directory: /home/litingyu/.cache/pip/wheels/b9/0a/c0/fc0de68aa14c7066272aed9fdf29080aad637f3530d865ac86
#   Building wheel for demucs (setup.py) ... done
#   Created wheel for demucs: filename=demucs-4.0.0-py3-none-any.whl size=76523 sha256=ae71059e0352014cad8e91d7c20d54d453946c2d956af6fb55c1c2e5b98bb31c
#   Stored in directory: /home/litingyu/.cache/pip/wheels/e2/2a/98/7d4c0856197f7c91073d22ca116082ace059b92416c74684e9
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21894 sha256=45cb6a9e35b8a2130cc710e5a64f15efdbc923e6b109ce77a1eed09f4addfec6
#   Stored in directory: /home/litingyu/.cache/pip/wheels/be/d0/90/d36b2adb0b0c4041f388245d5f1d68047bd84c7f1edfba7a89
#   Building wheel for dora-search (PEP 517) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75091 sha256=9ec7785234b5d8240e98571cfd8bec6830d59b48484f0eeaf116a655bf561738
#   Stored in directory: /home/litingyu/.cache/pip/wheels/9d/05/5b/586fcc8f7b7eb485bae33004cfddc1975ed6a7d2f8c7ef8d85
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.1-py3-none-any.whl size=5596 sha256=048da9b2e367a4cdf26ab610d5f0ea92e356f70eadcb916da297aded0242a11c
#   Stored in directory: /home/litingyu/.cache/pip/wheels/73/97/9a/829305d0106079dc317f9b12328693a7175003bad64e4f5bdf
#   Building wheel for lit (PEP 517) ... done
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93583 sha256=754581ca140ef3f15370b3874e520cd8e7dd45c8ca20ec842946146a5fe999f6
#   Stored in directory: /home/litingyu/.cache/pip/wheels/9c/3d/43/1038b6c210fef66984d18cdf338e319d07e60e1b074a30b374
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=8d5071459bb26b7488bcd7ff7f35824c4150995faa99ed5b822da7d9f9b18a9a
#   Stored in directory: /home/litingyu/.cache/pip/wheels/6b/88/e3/8c9b3f2ede2bf8f1c163dc9f03b8f090828552f510e06a3c3f
#   Building wheel for treetable (setup.py) ... done
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7349 sha256=3a22ef1a28478a4c53a8db9a7d75c3c0d5d5e733b461600f917bc000bbdc8549
#   Stored in directory: /home/litingyu/.cache/pip/wheels/02/f8/30/7e1b593261d92a5d254ec9e38e275b203a977ed5515f7092d0
# Successfully built audiocraft flashy antlr4-python3-runtime demucs julius dora-search ffmpy lit docopt treetable
# Installing collected packages: nvidia-cublas-cu11, lit, cmake, typing-extensions, triton, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-cusolver-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cudnn-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, h11, catalogue, uc-micro-py, torch, srsly, pydantic, murmurhash, httpcore, cymem, antlr4-python3-runtime, websockets, wasabi, typing-inspect, typer, treetable, torchaudio, submitit, starlette, smart-open, retrying, preshed, omegaconf, linkify-it-py, huggingface-hub, httpx, confection, blis, uvicorn, tokenizers, thinc, spacy-loggers, spacy-legacy, semantic-version, safetensors, python-multipart, pyre-extensions, pydub, pathy, orjson, openunmix, mdit-py-plugins, langcodes, lameenc, julius, importlib-resources, hydra-core, gradio-client, ffmpy, fastapi, einops, dora-search, docopt, diffq, colorlog, altair, aiofiles, xformers, transformers, spacy, num2words, hydra-colorlog, gradio, flashy, demucs, av, audiocraft
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
# ERROR: Could not install packages due to an OSError: [Errno 28] 设备上没有空间

# %%
from audiocraft.models import MusicGen
from audiocraft.models import MultiBandDiffusion
import torch
USE_DIFFUSION_DECODER = False
# Using small model, better results would be obtained with `medium` or `large`.
model = MusicGen.get_pretrained('facebook/musicgen-small')
if USE_DIFFUSION_DECODER:
    mbd = MultiBandDiffusion.get_mbd_musicgen()

# %% [markdown]
# Next, let us configure the generation parameters. Specifically, you can control the following:
# * `use_sampling` (bool, optional): use sampling if True, else do argmax decoding. Defaults to True.
# * `top_k` (int, optional): top_k used for sampling. Defaults to 250.
# * `top_p` (float, optional): top_p used for sampling, when set to 0 top_k is used. Defaults to 0.0.
# * `temperature` (float, optional): softmax temperature parameter. Defaults to 1.0.
# * `duration` (float, optional): duration of the generated waveform. Defaults to 30.0.
# * `cfg_coef` (float, optional): coefficient used for classifier free guidance. Defaults to 3.0.
#
# When left unchanged, MusicGen will revert to its default parameters.

# %%
model.set_generation_params(
    use_sampling=True,
    top_k=250,
    duration=30
)

# %% [markdown]
# Next, we can go ahead and start generating music using one of the following modes:
# * Unconditional samples using `model.generate_unconditional`
# * Music continuation using `model.generate_continuation`
# * Text-conditional samples using `model.generate`
# * Melody-conditional samples using `model.generate_with_chroma`

# %% [markdown]
# ### Music Continuation

# %%
import math
import torchaudio
import torch
from audiocraft.utils.notebook import display_audio

def get_bip_bip(bip_duration=0.125, frequency=440,
                duration=0.5, sample_rate=32000, device="cuda"):
    """Generates a series of bip bip at the given frequency."""
    t = torch.arange(
        int(duration * sample_rate), device="cuda", dtype=torch.float) / sample_rate
    wav = torch.cos(2 * math.pi * 440 * t)[None]
    tp = (t % (2 * bip_duration)) / (2 * bip_duration)
    envelope = (tp >= 0.5).float()
    return wav * envelope

# %%
# Here we use a synthetic signal to prompt both the tonality and the BPM
# of the generated audio.
res = model.generate_continuation(
    get_bip_bip(0.125).expand(2, -1, -1), 
    32000, ['Jazz jazz and only jazz', 
            'Heartful EDM with beautiful synths and chords'], 
    progress=True)
display_audio(res, 32000)

# %%
# You can also use any audio from a file. Make sure to trim the file if it is too long!
prompt_waveform, prompt_sr = torchaudio.load("../assets/bach.mp3")
prompt_duration = 2
prompt_waveform = prompt_waveform[..., :int(prompt_duration * prompt_sr)]
output = model.generate_continuation(prompt_waveform, prompt_sample_rate=prompt_sr, progress=True, return_tokens=True)
display_audio(output[0], sample_rate=32000)
if USE_DIFFUSION_DECODER:
    out_diffusion = mbd.tokens_to_wav(output[1])
    display_audio(out_diffusion, sample_rate=32000)

# %% [markdown]
# ### Text-conditional Generation

# %%
from audiocraft.utils.notebook import display_audio

output = model.generate(
    descriptions=[
        #'80s pop track with bassy drums and synth',
        #'90s rock song with loud guitars and heavy drums',
        #'Progressive rock drum and bass solo',
        #'Punk Rock song with loud drum and power guitar',
        #'Bluesy guitar instrumental with soulful licks and a driving rhythm section',
        #'Jazz Funk song with slap bass and powerful saxophone',
        'drum and bass beat with intense percussions'
    ],
    progress=True, return_tokens=True
)
display_audio(output[0], sample_rate=32000)
if USE_DIFFUSION_DECODER:
    out_diffusion = mbd.tokens_to_wav(output[1])
    display_audio(out_diffusion, sample_rate=32000)

# %% [markdown]
# ### Melody-conditional Generation

# %%
import torchaudio
from audiocraft.utils.notebook import display_audio

model = MusicGen.get_pretrained('facebook/musicgen-melody')
model.set_generation_params(duration=8)

melody_waveform, sr = torchaudio.load("../assets/bach.mp3")
melody_waveform = melody_waveform.unsqueeze(0).repeat(2, 1, 1)
output = model.generate_with_chroma(
    descriptions=[
        '80s pop track with bassy drums and synth',
        '90s rock song with loud guitars and heavy drums',
    ],
    melody_wavs=melody_waveform,
    melody_sample_rate=sr,
    progress=True, return_tokens=True
)
display_audio(output[0], sample_rate=32000)
if USE_DIFFUSION_DECODER:
    out_diffusion = mbd.tokens_to_wav(output[1])
    display_audio(out_diffusion, sample_rate=32000)
